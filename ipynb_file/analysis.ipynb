# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../clean_data/cleaned_data.csv")
df.head(2)
# Out:
#    Unnamed: 0  Age            Job Marital_Status     Education  Annual_Income  \
# 0           0   43  Self-Employed        Married  Not Graduate        1069085
# 1           1   34       Services         Single      Graduate         278319
#
#    Credit_Score  Account_Balance Housing_Loan Personal_Loan Contacted_Before  \
# 0           741            50353          Yes            No               No
# 1           710            86208           No            No               No
#
#    Campaign_Count  Months_With_Bank Subscribed
# 0               4                84         No
# 1               7                73         No

# %%
# df.drop(columns="Unnamed: 0", inplace=True)
df.describe()
# Out:
#                Age  Annual_Income  Credit_Score  Account_Balance  \
# count  4996.000000   4.996000e+03   4996.000000     4.996000e+03
# mean     39.556845   6.490002e+05    689.455965     9.930044e+04
# std      10.828861   6.540326e+05     69.293886     3.314609e+05
# min      18.000000   5.000000e+03    100.000000    -1.000000e+04
# 25%      32.000000   3.821620e+05    643.000000     2.168100e+04
# 50%      39.000000   5.531070e+05    689.000000     8.347100e+04
# 75%      47.000000   7.867550e+05    735.000000     1.430078e+05
# max      75.000000   3.000000e+07    999.000000     2.000000e+07
#
#        Campaign_Count  Months_With_Bank
# count     4996.000000       4996.000000
# mean         3.356685         73.170136
# std          2.155998         46.762967
# min         -2.000000         -5.000000
# 25%          2.000000         39.000000
# 50%          3.000000         73.000000
# 75%          4.000000        103.000000
# max        100.000000       1000.000000

# %%
df["Subscribed"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Subscribed'>

# %%
df['Age'].hist()
# Out:
# <Axes: >

# %%
pd.crosstab(
    df["Education"],
    df["Subscribed"]
)
# Out:
# Subscribed      No   Yes
# Education
# Graduate      2160  1274
# Not Graduate  1090   472

# %%
pd.crosstab(
    df["Job"],
    df["Subscribed"]
)
# Out:
# Subscribed      No  Yes
# Job
# Admin          447  216
# Entrepreneur   382  181
# Management     336  207
# Retired        304  236
# Self-Employed  366  193
# Services       359  183
# Student        349  160
# Technician     374  175
# Unemployed     333  195

# %%
df.boxplot(
    column="Credit_Score",
    by="Subscribed"
)

plt.show()
